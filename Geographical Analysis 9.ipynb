# %% [markdown]
# # Geographical analysis

# %% [markdown]
# ## Importing libraries

# %%
import pandas as pd
import numpy as np
import os

import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# Maps visualisation
import geopandas as gpd
from geopandas import GeoDataFrame

# Dataframe
from shapely.geometry import Point, Polygon

# %% [markdown]
# ## Importing and understanding database

# %%
crimes = pd.read_csv("/Users/oleoaraujo/Desktop/Crimes-in-Chicago/Crimes_-_2016_to_2020.csv")

# %%
crimes.head(20)
# Out:
#           ID Case Number                 Date                  Block  \
# 0   11646166    JC213529  2018-09-01 00:01:00  082XX S INGLESIDE AVE
# 1   11645836    JC212333  2016-05-01 00:25:00    055XX S ROCKWELL ST
# 2   12014684    JD189901  2020-03-17 21:30:00   039XX N LECLAIRE AVE
# 3   11645648    JC212959  2018-01-01 08:00:00    024XX N MONITOR AVE
# 4   11864018    JC476123  2019-09-24 08:00:00   022XX S MICHIGAN AVE
# 5   11859805    JC471592  2019-10-13 20:30:00    024XX W CHICAGO AVE
# 6   11645959    JC211511  2018-12-20 16:00:00     045XX N ALBANY AVE
# 7   11645557    JC212685  2018-04-01 00:01:00     080XX S VERNON AVE
# 8   11646293    JC213749  2018-12-20 15:00:00   023XX N LOCKWOOD AVE
# 9   12012127    JD189186  2020-03-18 02:03:00   039XX W JACKSON BLVD
# 10  11863808    JC476236  2019-10-05 18:30:00      0000X N LOOMIS ST
# 11  11227287    JB147188  2017-10-08 03:00:00     092XX S RACINE AVE
# 12  11227583    JB147595  2017-03-28 14:00:00        026XX W 79TH ST
# 13  11227293    JB147230  2017-09-09 20:17:00   060XX S EBERHART AVE
# 14  11227634    JB147599  2017-08-26 10:00:00    001XX W RANDOLPH ST
# 15  11645568    JC212803  2018-12-18 11:00:00     032XX N WILTON AVE
# 16  11859727    JC471542  2019-10-13 19:00:00     016XX W ADDISON ST
# 17  11859656    JC471240  2019-10-13 14:10:00       051XX N BROADWAY
# 18  11227508    JB146365  2017-01-01 00:01:00     027XX S WHIPPLE ST
# 19  11022695    JA353568  2017-07-17 10:10:00    021XX W MC LEAN AVE
#
#      Crime_Type                Primary Type  \
# 0   MISDEMEANOR                       THEFT
# 1   MISDEMEANOR          DECEPTIVE PRACTICE
# 2   MISDEMEANOR                       THEFT
# 3   MISDEMEANOR          DECEPTIVE PRACTICE
# 4   MISDEMEANOR          DECEPTIVE PRACTICE
# 5   MISDEMEANOR                       THEFT
# 6    INFRACTION               OTHER OFFENSE
# 7   MISDEMEANOR          DECEPTIVE PRACTICE
# 8   MISDEMEANOR          DECEPTIVE PRACTICE
# 9   MISDEMEANOR         MOTOR VEHICLE THEFT
# 10  MISDEMEANOR                       THEFT
# 11       FELONY     CRIMINAL SEXUAL ASSAULT
# 12       FELONY                    BURGLARY
# 13  MISDEMEANOR                       THEFT
# 14       FELONY     CRIMINAL SEXUAL ASSAULT
# 15  MISDEMEANOR          DECEPTIVE PRACTICE
# 16       FELONY             CRIMINAL DAMAGE
# 17  MISDEMEANOR                     ASSAULT
# 18       FELONY  OFFENSE INVOLVING CHILDREN
# 19  MISDEMEANOR                       THEFT
#
#                                 Description          Location Description  \
# 0                                 OVER $500                     RESIDENCE
# 1       FINANCIAL IDENTITY THEFT OVER $ 300                           NaN
# 2                            $500 AND UNDER                        STREET
# 3       FINANCIAL IDENTITY THEFT OVER $ 300                     RESIDENCE
# 4   FINANCIAL IDENTITY THEFT $300 AND UNDER  COMMERCIAL / BUSINESS OFFICE
# 5                              RETAIL THEFT            GROCERY FOOD STORE
# 6                          TELEPHONE THREAT                     RESIDENCE
# 7       FINANCIAL IDENTITY THEFT OVER $ 300                     RESIDENCE
# 8   FINANCIAL IDENTITY THEFT $300 AND UNDER                     APARTMENT
# 9                                AUTOMOBILE                     APARTMENT
# 10                                OVER $500                     RESIDENCE
# 11                           NON-AGGRAVATED                     RESIDENCE
# 12                           UNLAWFUL ENTRY                         OTHER
# 13                                OVER $500                     RESIDENCE
# 14                           NON-AGGRAVATED                   HOTEL/MOTEL
# 15      FINANCIAL IDENTITY THEFT OVER $ 300                     RESIDENCE
# 16                               TO VEHICLE                        STREET
# 17                                   SIMPLE                   GAS STATION
# 18           AGG SEX ASSLT OF CHILD FAM MBR                     RESIDENCE
# 19                                OVER $500                     RESIDENCE
#
#     Arrest  Domestic  Beat  District  Ward  Community Area  Year  \
# 0        0         1   631       6.0   8.0            44.0  2018
# 1        0         0   824       8.0  15.0            63.0  2016
# 2        0         0  1634      16.0  45.0            15.0  2020
# 3        0         0  2515      25.0  30.0            19.0  2018
# 4        0         0   132       1.0   3.0            33.0  2019
# 5        0         0  1221      12.0  26.0            24.0  2019
# 6        0         0  1724      17.0  33.0            14.0  2018
# 7        0         0   631       6.0   6.0            44.0  2018
# 8        0         0  2515      25.0  36.0            19.0  2018
# 9        0         1  1132      11.0  28.0            26.0  2020
# 10       0         0  1224      12.0  27.0            28.0  2019
# 11       0         0  2222      22.0  21.0            73.0  2017
# 12       0         0   835       8.0  18.0            70.0  2017
# 13       0         0   313       3.0  20.0            42.0  2017
# 14       0         0   122       1.0  42.0            32.0  2017
# 15       0         0  1924      19.0  44.0             6.0  2018
# 16       0         0  1922      19.0  47.0             6.0  2019
# 17       0         0  2033      20.0  47.0             3.0  2019
# 18       0         0  1033      10.0  12.0            30.0  2017
# 19       0         0  1432      14.0  32.0            22.0  2017
#
#              Updated On   Latitude  Longitude                       Location
# 0   2019-04-06 16:04:43        NaN        NaN                            NaN
# 1   2019-04-06 16:04:43        NaN        NaN                            NaN
# 2   2020-03-25 15:45:43  41.952052 -87.754660  (41.952051946, -87.754660372)
# 3   2019-04-06 16:04:43        NaN        NaN                            NaN
# 4   2019-10-20 15:56:02  41.852248 -87.623786  (41.852248185, -87.623786256)
# 5   2019-10-20 16:03:03  41.895732 -87.687784  (41.895732399, -87.687784384)
# 6   2019-04-06 16:04:43        NaN        NaN                            NaN
# 7   2019-04-06 16:04:43        NaN        NaN                            NaN
# 8   2019-04-06 16:04:43        NaN        NaN                            NaN
# 9   2020-03-25 15:47:29  41.877110 -87.723990  (41.877110187, -87.723989719)
# 10  2019-10-20 15:56:02  41.882002 -87.662287   (41.88200224, -87.662286977)
# 11  2018-02-11 15:57:41        NaN        NaN                            NaN
# 12  2018-02-11 15:57:41        NaN        NaN                            NaN
# 13  2018-02-11 15:57:41        NaN        NaN                            NaN
# 14  2018-02-11 15:57:41        NaN        NaN                            NaN
# 15  2019-04-06 16:04:43        NaN        NaN                            NaN
# 16  2019-10-20 16:03:03  41.946987 -87.669164  (41.946987144, -87.669163602)
# 17  2019-10-20 16:03:03  41.975838 -87.659854  (41.975837637, -87.659853835)
# 18  2018-02-11 15:57:41        NaN        NaN                            NaN
# 19  2017-07-24 15:54:23        NaN        NaN                            NaN

# %%
crimes.set_index(crimes.ID, inplace=True)

# %%
crimes.describe(include='all').T
# Out:
#                           count   unique                            top  \
# ID                    1277232.0      NaN                            NaN
# Case Number             1277232  1277072                       HZ140230
# Date                    1277232   589815            2017-01-01 00:01:00
# Block                   1277232    34700               001XX N STATE ST
# Crime_Type              1277094        4                    MISDEMEANOR
# Primary Type            1277232       32                          THEFT
# Description             1277232      491                         SIMPLE
# Location Description    1271428      190                         STREET
# Arrest                1277232.0      NaN                            NaN
# Domestic              1277232.0      NaN                            NaN
# Beat                  1277232.0      NaN                            NaN
# District              1277231.0      NaN                            NaN
# Ward                  1277203.0      NaN                            NaN
# Community Area        1277231.0      NaN                            NaN
# Year                  1277232.0      NaN                            NaN
# Updated On              1277232     3128            2018-02-10 15:50:01
# Latitude              1263290.0      NaN                            NaN
# Longitude             1263290.0      NaN                            NaN
# Location                1263290   333826  (41.883500187, -87.627876698)
#
#                         freq             mean            std        min  \
# ID                       NaN  11302467.393457  783643.814895    22245.0
# Case Number                6              NaN            NaN        NaN
# Date                     168              NaN            NaN        NaN
# Block                   4326              NaN            NaN        NaN
# Crime_Type            626741              NaN            NaN        NaN
# Primary Type          294745              NaN            NaN        NaN
# Description           140645              NaN            NaN        NaN
# Location Description  286880              NaN            NaN        NaN
# Arrest                   NaN         0.194647       0.395929        0.0
# Domestic                 NaN         0.166526       0.372552        0.0
# Beat                     NaN      1143.700576     695.430329      111.0
# District                 NaN         11.20845        6.94722        1.0
# Ward                     NaN        23.222541      13.975698        1.0
# Community Area           NaN        36.778095        21.4319        1.0
# Year                     NaN      2017.900504       1.380767     2016.0
# Updated On            487694              NaN            NaN        NaN
# Latitude                 NaN        41.843492       0.086297  36.619446
# Longitude                NaN       -87.670533       0.059106 -91.686566
# Location                2248              NaN            NaN        NaN
#
#                               25%         50%          75%         max
# ID                    10882663.75  11333324.5  11784053.25  12305810.0
# Case Number                   NaN         NaN          NaN         NaN
# Date                          NaN         NaN          NaN         NaN
# Block                         NaN         NaN          NaN         NaN
# Crime_Type                    NaN         NaN          NaN         NaN
# Primary Type                  NaN         NaN          NaN         NaN
# Description                   NaN         NaN          NaN         NaN
# Location Description          NaN         NaN          NaN         NaN
# Arrest                        0.0         0.0          0.0         1.0
# Domestic                      0.0         0.0          0.0         1.0
# Beat                        612.0      1024.0       1713.0      2535.0
# District                      6.0        10.0         17.0        31.0
# Ward                         10.0        24.0         34.0        50.0
# Community Area               23.0        32.0         54.0        77.0
# Year                       2017.0      2018.0       2019.0      2020.0
# Updated On                    NaN         NaN          NaN         NaN
# Latitude                41.768534   41.863197    41.905098   42.022671
# Longitude              -87.713031  -87.664054   -87.627842  -87.524529
# Location                      NaN         NaN          NaN         NaN

# %%
crimes.dtypes
# Out:
# ID                        int64
# Case Number              object
# Date                     object
# Block                    object
# Crime_Type               object
# Primary Type             object
# Description              object
# Location Description     object
# Arrest                    int64
# Domestic                  int64
# Beat                      int64
# District                float64
# Ward                    float64
# Community Area          float64
# Year                      int64
# Updated On               object
# Latitude                float64
# Longitude               float64
# Location                 object
# dtype: object

# %%
# Define "Date" and "Updated on" columns as datetime type
crimes.Date = pd.to_datetime(crimes.Date)
crimes["Updated On"] = pd.to_datetime(crimes["Updated On"])

crimes.dtypes
# Out:
# ID                               int64
# Case Number                     object
# Date                    datetime64[ns]
# Block                           object
# Crime_Type                      object
# Primary Type                    object
# Description                     object
# Location Description            object
# Arrest                           int64
# Domestic                         int64
# Beat                             int64
# District                       float64
# Ward                           float64
# Community Area                 float64
# Year                             int64
# Updated On              datetime64[ns]
# Latitude                       float64
# Longitude                      float64
# Location                        object
# dtype: object

# %% [markdown]
# ## Importing Chicago Maps

# %%
chicago_geo = gpd.read_file('Chicago - Community Areas/geo_export_47927303-22ce-4ba2-9ded-092e5c8390c3.shp')

# %%
chicago_geo.head()
# Out:
#    area area_num_1 area_numbe  comarea  comarea_id        community  \
# 0   0.0         35         35      0.0         0.0          DOUGLAS
# 1   0.0         36         36      0.0         0.0          OAKLAND
# 2   0.0         37         37      0.0         0.0      FULLER PARK
# 3   0.0         38         38      0.0         0.0  GRAND BOULEVARD
# 4   0.0         39         39      0.0         0.0          KENWOOD
#
#    perimeter    shape_area     shape_len  \
# 0        0.0  4.600462e+07  31027.054510
# 1        0.0  1.691396e+07  19565.506153
# 2        0.0  1.991670e+07  25339.089750
# 3        0.0  4.849250e+07  28196.837157
# 4        0.0  2.907174e+07  23325.167906
#
#                                             geometry
# 0  POLYGON ((-87.60914 41.84469, -87.60915 41.844...
# 1  POLYGON ((-87.59215 41.81693, -87.59231 41.816...
# 2  POLYGON ((-87.62880 41.80189, -87.62879 41.801...
# 3  POLYGON ((-87.60671 41.81681, -87.60670 41.816...
# 4  POLYGON ((-87.59215 41.81693, -87.59215 41.816...

# %%
chicago_map = chicago_geo.plot(figsize=(30,30), edgecolor='k', cmap='nipy_spectral', alpha=0.5, linewidth=2) 
chicago_geo.apply(lambda x: chicago_map.annotate(s=x.community, xy=x.geometry.centroid.coords[0], ha='center', size=16),axis=1);
chicago_map.set_axis_off()
# Out:
# <ipython-input-10-c6db8bb24788>:2: MatplotlibDeprecationWarning: The 's' parameter of annotate() has been renamed 'text' since Matplotlib 3.3; support for the old name will be dropped two minor releases later.
#   chicago_geo.apply(lambda x: chicago_map.annotate(s=x.community, xy=x.geometry.centroid.coords[0], ha='center', size=16),axis=1);

# %%
chicago_geo.plot()
# Out:
# <AxesSubplot:>

# %%
# Testing another type of plot for the Chicago Map
import geoplot
#plt.figure(figsize=(16,10))
geoplot.polyplot(chicago_geo, figsize=(16, 10))
#chicago_geo.plot()
# Out:
# <AxesSubplot:>

# %%
# Creating Geopandas DataFrame for the known points of our database
chicago_crimes = gpd.GeoDataFrame(crimes, geometry=gpd.points_from_xy(crimes.Longitude, crimes.Latitude))

# %%
# Ploting the geopandas created, we may notice some points with errors in Latitude and Longitude
chicago_crimes.plot()
# Out:
# <AxesSubplot:>

# %%
# Cleaning the Latitude and Longitude
chicago_crimes.dropna(inplace=True)
chicago_crimes = chicago_crimes[(chicago_crimes.Latitude>41.0)&(chicago_crimes.Longitude>-89.0)]
chicago_crimes.plot()
# Out:
# <AxesSubplot:>

# %% [markdown]
# ### Plotting both graphs together

# %%
chicago_map = chicago_geo.plot(figsize=(16,16), edgecolor='k', facecolor='g', alpha=0.25, linewidth=2) 
chicago_geo.apply(lambda x: chicago_map.annotate(text=x.community, xy=x.geometry.centroid.coords[0], ha='center', size=10),axis=1);
chicago_crimes.plot(figsize=(16,16),ax=chicago_map, markersize=5, color='r', alpha=0.25)
chicago_map.set_axis_off()

# %%
import mplleaflet

# %%
import mplleaflet

#chicago_map = chicago_geo.plot(figsize=(16,16), edgecolor='k', facecolor='b', alpha=0.25, linewidth=2) 
#chicago_geo.apply(lambda x: chicago_map.annotate(text=x.community, xy=x.geometry.centroid.coords[0], ha='center', size=10),axis=1);

geoplot.pointplot(chicago_crimes, s=1, color='black', ax=ax)
geoplot.webmap(chicago_map, ax=ax)

#chicago_crimes.plot(figsize=(16,16),ax=chicago_map, markersize=5, color='r', alpha=0.25)
#chicago_map.set_axis_off()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-20-7c0db68970c2> in <module>
#       4 #chicago_geo.apply(lambda x: chicago_map.annotate(text=x.community, xy=x.geometry.centroid.coords[0], ha='center', size=10),axis=1);
#       5
# ----> 6 geoplot.pointplot(chicago_crimes, s=1, color='black', ax=ax)
#       7 geoplot.webmap(chicago_map, ax=ax)
#       8
#
# NameError: name 'ax' is not defined

# %% [raw]
# import geoplot.crs as gcrs
# ax = geoplot.kdeplot(chicago_crimes, cmap='viridis', projection=gcrs.WebMercator(), figsize=(12, 12),shade=True)

# %% [raw]
# ax = geoplot.kdeplot(chicago_crimes, projection=gcrs.AlbersEqualArea(), cmap="Reds", figsize=(16, 16),shade=True)
