# %% [markdown]
# # Arrests analysis

# %% [markdown]
# ## Importing libraries

# %%
import pandas as pd
import numpy as np
import os

from matplotlib import pyplot
# %matplotlib inline

# %% [markdown]
# ## Importing database

# %%
crimes = pd.read_csv("/Users/oleoaraujo/Desktop/Crimes-in-Chicago/Crimes_-_2015_to_2020.csv")

# %%
crimes.head(20)
# Out:
#           ID Case Number                 Date                    Block  \
# 0   10224738    HY411648  2015-09-05 13:30:00          043XX S WOOD ST
# 1   10224739    HY411615  2015-09-04 11:30:00      008XX N CENTRAL AVE
# 2   11646166    JC213529  2018-09-01 00:01:00    082XX S INGLESIDE AVE
# 3   10224740    HY411595  2015-09-05 12:45:00        035XX W BARRY AVE
# 4   10224741    HY411610  2015-09-05 13:00:00      0000X N LARAMIE AVE
# 5   10224742    HY411435  2015-09-05 10:55:00      082XX S LOOMIS BLVD
# 6   10224743    HY411629  2015-09-04 18:00:00     021XX W CHURCHILL ST
# 7   10224744    HY411605  2015-09-05 13:00:00        025XX W CERMAK RD
# 8   10224745    HY411654  2015-09-05 11:30:00  031XX W WASHINGTON BLVD
# 9   11645836    JC212333  2016-05-01 00:25:00      055XX S ROCKWELL ST
# 10  10224746    HY411662  2015-09-05 14:00:00       071XX S PULASKI RD
# 11  10224749    HY411626  2015-09-05 11:00:00    052XX N MILWAUKEE AVE
# 12  10224750    HY411632  2015-09-05 03:00:00         0000X W 103RD ST
# 13  10224751    HY411566  2015-09-05 12:50:00          013XX E 47TH ST
# 14  10224752    HY411601  2015-09-03 13:00:00      020XX W SCHILLER ST
# 15  10224753    HY411489  2015-09-05 11:45:00       080XX S JUSTINE ST
# 16  10224754    HY411656  2015-09-05 13:30:00   007XX N LEAMINGTON AVE
# 17  10224756    HY410094  2015-07-08 00:00:00     103XX S TORRENCE AVE
# 18  10224757    HY411388  2015-09-05 09:55:00       088XX S PAULINA ST
# 19  10224758    HY411568  2015-09-05 12:35:00         059XX W GRACE ST
#
#           Primary Type                                     Description  \
# 0              BATTERY                         DOMESTIC BATTERY SIMPLE
# 1                THEFT                                  POCKET-PICKING
# 2                THEFT                                       OVER $500
# 3            NARCOTICS                           POSS: HEROIN(BRN/TAN)
# 4              ASSAULT                                          SIMPLE
# 5             BURGLARY                                  FORCIBLE ENTRY
# 6             BURGLARY                                  UNLAWFUL ENTRY
# 7                THEFT                                    RETAIL THEFT
# 8              ROBBERY                           STRONGARM - NO WEAPON
# 9   DECEPTIVE PRACTICE             FINANCIAL IDENTITY THEFT OVER $ 300
# 10               THEFT                                  $500 AND UNDER
# 11             BATTERY                                          SIMPLE
# 12       OTHER OFFENSE                                TELEPHONE THREAT
# 13             BATTERY                         DOMESTIC BATTERY SIMPLE
# 14               THEFT                                       OVER $500
# 15             BATTERY  AGGRAVATED DOMESTIC BATTERY: OTHER DANG WEAPON
# 16     CRIMINAL DAMAGE                                      TO VEHICLE
# 17            BURGLARY                                  UNLAWFUL ENTRY
# 18            BURGLARY                                  FORCIBLE ENTRY
# 19             BATTERY                         DOMESTIC BATTERY SIMPLE
#
#               Location Description  Arrest  Domestic  Beat  District  Ward  \
# 0                        RESIDENCE   False      True   924       9.0  12.0
# 1                          CTA BUS   False     False  1511      15.0  29.0
# 2                        RESIDENCE   False      True   631       6.0   8.0
# 3                         SIDEWALK    True     False  1412      14.0  35.0
# 4                        APARTMENT   False      True  1522      15.0  28.0
# 5                        RESIDENCE   False     False   614       6.0  21.0
# 6                 RESIDENCE-GARAGE   False     False  1434      14.0  32.0
# 7               GROCERY FOOD STORE    True     False  1034      10.0  25.0
# 8                           STREET   False      True  1222      12.0  27.0
# 9                              NaN   False     False   824       8.0  15.0
# 10  PARKING LOT/GARAGE(NON.RESID.)   False     False   833       8.0  13.0
# 11              SMALL RETAIL STORE   False     False  1623      16.0  45.0
# 12                       APARTMENT   False      True   512       5.0  34.0
# 13                          STREET   False      True   222       2.0   4.0
# 14                          STREET   False     False  1424      14.0   1.0
# 15                       APARTMENT   False     False   612       6.0  21.0
# 16                          STREET   False     False  1531      15.0  28.0
# 17                           OTHER   False     False   434       4.0  10.0
# 18                       RESIDENCE    True     False  2221      22.0  21.0
# 19                          STREET   False      True  1633      16.0  38.0
#
#     Community Area  Year           Updated On   Latitude  Longitude  \
# 0             61.0  2015  2018-02-10 15:50:01  41.815117 -87.670000
# 1             25.0  2015  2018-02-10 15:50:01  41.895080 -87.765400
# 2             44.0  2018  2019-04-06 16:04:43        NaN        NaN
# 3             21.0  2015  2018-02-10 15:50:01  41.937406 -87.716650
# 4             25.0  2015  2018-02-10 15:50:01  41.881903 -87.755121
# 5             71.0  2015  2018-02-10 15:50:01  41.744379 -87.658431
# 6             24.0  2015  2018-02-10 15:50:01  41.914636 -87.681631
# 7             31.0  2015  2015-09-17 11:37:18  41.851989 -87.689219
# 8             27.0  2015  2018-02-10 15:50:01  41.882814 -87.704326
# 9             63.0  2016  2019-04-06 16:04:43        NaN        NaN
# 10            65.0  2015  2018-02-10 15:50:01  41.763648 -87.722345
# 11            11.0  2015  2018-02-10 15:50:01  41.975968 -87.768014
# 12            49.0  2015  2018-02-10 15:50:01  41.707155 -87.624245
# 13            39.0  2015  2018-02-10 15:50:01  41.809678 -87.593639
# 14            24.0  2015  2018-02-10 15:50:01  41.907127 -87.678232
# 15            71.0  2015  2018-02-10 15:50:01  41.748097 -87.662166
# 16            25.0  2015  2018-02-10 15:50:01  41.893870 -87.754341
# 17            51.0  2015  2018-02-10 15:50:01  41.707490 -87.559650
# 18            71.0  2015  2018-02-10 15:50:01  41.733174 -87.665421
# 19            15.0  2015  2018-02-10 15:50:01  41.949430 -87.775436
#
#                          Location
# 0   (41.815117282, -87.669999562)
# 1   (41.895080471, -87.765400451)
# 2                             NaN
# 3   (41.937405765, -87.716649687)
# 4   (41.881903443, -87.755121152)
# 5   (41.744378879, -87.658430635)
# 6   (41.914635603, -87.681630909)
# 7   (41.851988885, -87.689219118)
# 8    (41.88281374, -87.704325717)
# 9                             NaN
# 10  (41.763647552, -87.722344693)
# 11  (41.975968415, -87.768014257)
# 12  (41.707154919, -87.624244993)
# 13  (41.809678314, -87.593638934)
# 14  (41.907127255, -87.678232016)
# 15  (41.748097343, -87.662166183)
# 16  (41.893869916, -87.754341096)
# 17  (41.707490122, -87.559650325)
# 18  (41.733173536, -87.665421067)
# 19  (41.949429769, -87.775435529)

# %%
crimes.set_index(crimes.ID, inplace=True)

# %%
crimes.describe(include='all').T
# Out:
#                           count   unique                            top  \
# ID                    1541733.0      NaN                            NaN
# Case Number             1541733  1541546                       HZ140230
# Date                    1541733   702137            2015-01-01 00:01:00
# Block                   1541733    35135               001XX N STATE ST
# Primary Type            1541733       35                          THEFT
# Description             1541733      492                         SIMPLE
# Location Description    1535379      192                         STREET
# Arrest                  1541733        2                          False
# Domestic                1541733        2                          False
# Beat                  1541733.0      NaN                            NaN
# District              1541732.0      NaN                            NaN
# Ward                  1541702.0      NaN                            NaN
# Community Area        1541732.0      NaN                            NaN
# Year                  1541733.0      NaN                            NaN
# Updated On              1541733     3539            2018-02-10 15:50:01
# Latitude              1521192.0      NaN                            NaN
# Longitude             1521192.0      NaN                            NaN
# Location                1521192   368492  (41.883500187, -87.627876698)
#
#                          freq             mean            std        min  \
# ID                        NaN  11102325.804722  860134.560531    21714.0
# Case Number                 6              NaN            NaN        NaN
# Date                      187              NaN            NaN        NaN
# Block                    5094              NaN            NaN        NaN
# Primary Type           352089              NaN            NaN        NaN
# Description            168057              NaN            NaN        NaN
# Location Description   347634              NaN            NaN        NaN
# Arrest                1223135              NaN            NaN        NaN
# Domestic              1287168              NaN            NaN        NaN
# Beat                      NaN      1143.751639     694.631456      111.0
# District                  NaN        11.208901       6.939356        1.0
# Ward                      NaN        23.152654        13.9437        1.0
# Community Area            NaN        36.914989      21.432076        1.0
# Year                      NaN      2017.402891       1.665876     2015.0
# Updated On             729832              NaN            NaN        NaN
# Latitude                  NaN        41.843167       0.086222  36.619446
# Longitude                 NaN       -87.670788       0.059251 -91.686566
# Location                 2738              NaN            NaN        NaN
#
#                              25%         50%         75%         max
# ID                    10571765.0  11156741.0  11687324.0  12305810.0
# Case Number                  NaN         NaN         NaN         NaN
# Date                         NaN         NaN         NaN         NaN
# Block                        NaN         NaN         NaN         NaN
# Primary Type                 NaN         NaN         NaN         NaN
# Description                  NaN         NaN         NaN         NaN
# Location Description         NaN         NaN         NaN         NaN
# Arrest                       NaN         NaN         NaN         NaN
# Domestic                     NaN         NaN         NaN         NaN
# Beat                       612.0      1024.0      1712.0      2535.0
# District                     6.0        10.0        17.0        31.0
# Ward                        10.0        24.0        34.0        50.0
# Community Area              23.0        32.0        54.0        77.0
# Year                      2016.0      2017.0      2019.0      2020.0
# Updated On                   NaN         NaN         NaN         NaN
# Latitude               41.768287   41.862363    41.90495   42.022671
# Longitude             -87.713599  -87.664343  -87.627845  -87.524529
# Location                     NaN         NaN         NaN         NaN

# %%
crimes.dtypes
# Out:
# ID                        int64
# Case Number              object
# Date                     object
# Block                    object
# Primary Type             object
# Description              object
# Location Description     object
# Arrest                     bool
# Domestic                   bool
# Beat                      int64
# District                float64
# Ward                    float64
# Community Area          float64
# Year                      int64
# Updated On               object
# Latitude                float64
# Longitude               float64
# Location                 object
# dtype: object

# %%
# Define "Date" and "Updated on" columns as datetime type
crimes.Date = pd.to_datetime(crimes.Date)
crimes["Updated On"] = pd.to_datetime(crimes["Updated On"])

crimes.dtypes
# Out:
# ID                               int64
# Case Number                     object
# Date                    datetime64[ns]
# Block                           object
# Primary Type                    object
# Description                     object
# Location Description            object
# Arrest                            bool
# Domestic                          bool
# Beat                             int64
# District                       float64
# Ward                           float64
# Community Area                 float64
# Year                             int64
# Updated On              datetime64[ns]
# Latitude                       float64
# Longitude                      float64
# Location                        object
# dtype: object

# %% [markdown]
# ## Arrests

# %%
crimes.Arrest.describe()
# Out:
# count     1541733
# unique          2
# top         False
# freq      1223135
# Name: Arrest, dtype: object
